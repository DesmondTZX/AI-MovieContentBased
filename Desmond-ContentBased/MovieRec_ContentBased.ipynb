# %%
# importing required libraries
import pandas as pd
import numpy as np

from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity

from itertools import combinations

# %%
# load the dataset
movies_df = pd.read_csv('movies.csv', nrows=62424)
tags_df = pd.read_csv('tags.csv', nrows=62424)

# %%
# dropping any unused columns
tags_df = tags_df.drop(['userId', 'timestamp'], axis = 1).reset_index(drop=True)

# %%
# check for missing values
movies_df.isnull().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
# check for missing values
tags_df.isnull().sum()
# Out:
# movieId    0
# tag        0
# dtype: int64

# %%
# show result
movies_df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
# show result
tags_df
# Out:
#        movieId               tag
# 0          260           classic
# 1          260            sci-fi
# 2         1732       dark comedy
# 3         1732    great dialogue
# 4         7569  so bad it's good
# ...        ...               ...
# 62419     3289             money
# 62420     3289          mountain
# 62421     3289           promise
# 62422     3289           teacher
# 62423     3289           village
#
# [62424 rows x 2 columns]

# %%
# removing null values from tag
tags_df['tag'] = tags_df['tag'].apply(lambda x: '' if pd.isnull(x) else x)

# grouping tags with the same movieId
tags_combined_df = tags_df.groupby('movieId')['tag'].agg(lambda x: '|'.join(x)).reset_index()

# show result
tags_combined_df
# Out:
#       movieId                                                tag
# 0           1  Owned|imdb top 250|Pixar|Pixar|time travel|chi...
# 1           2  Robin Williams|time travel|fantasy|based on ch...
# 2           3  funny|best friend|duringcreditsstinger|fishing...
# 3           4  based on novel or book|chick flick|divorce|int...
# 4           5  aging|baby|confidence|contraception|daughter|g...
# ...       ...                                                ...
# 6995   204878                                funny|Wesley Snipes
# 6996   205383                                       breaking bad
# 6997   206024                                              MMsWL
# 6998   206399                                              MMsWL
# 6999   206727  bad language|political|racist humor|sexist jok...
#
# [7000 rows x 2 columns]

# %%
# Merge tags with movies
merged = pd.merge(movies_df, tags_combined_df, on='movieId', how='left')
merged
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
#                                                      tag
# 0      Owned|imdb top 250|Pixar|Pixar|time travel|chi...
# 1      Robin Williams|time travel|fantasy|based on ch...
# 2      funny|best friend|duringcreditsstinger|fishing...
# 3      based on novel or book|chick flick|divorce|int...
# 4      aging|baby|confidence|contraception|daughter|g...
# ...                                                  ...
# 62418                                                NaN
# 62419                                                NaN
# 62420                                                NaN
# 62421                                                NaN
# 62422                                                NaN
#
# [62423 rows x 4 columns]

# %%
# Fill NaN values in 'tag' column with an empty string
merged['tag'] = merged['tag'].fillna('')

# %%
# removing any movies with no tags
merged = merged[merged['tag'] != ""]

# %%
# removing any movies with no genres
merged = merged[merged['genres'] != "(no genres listed)"]

# %%
# show result
merged[['movieId', 'title', 'genres', 'tag']]
# Out:
#        movieId                                   title  \
# 0            1                        Toy Story (1995)
# 1            2                          Jumanji (1995)
# 2            3                 Grumpier Old Men (1995)
# 3            4                Waiting to Exhale (1995)
# 4            5      Father of the Bride Part II (1995)
# ...        ...                                     ...
# 61073   204878              Dolemite Is My Name (2019)
# 61253   205383  El Camino: A Breaking Bad Movie (2019)
# 61482   206024            The Swallows of Kabul (2019)
# 61625   206399                         For Sama (2019)
# 61720   206727      Jeff Dunham: Beside Himself (2019)
#
#                                             genres  \
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 61073                                 Comedy|Drama
# 61253                         Crime|Drama|Thriller
# 61482                                    Animation
# 61625                                  Documentary
# 61720                                       Comedy
#
#                                                      tag
# 0      Owned|imdb top 250|Pixar|Pixar|time travel|chi...
# 1      Robin Williams|time travel|fantasy|based on ch...
# 2      funny|best friend|duringcreditsstinger|fishing...
# 3      based on novel or book|chick flick|divorce|int...
# 4      aging|baby|confidence|contraception|daughter|g...
# ...                                                  ...
# 61073                                funny|Wesley Snipes
# 61253                                       breaking bad
# 61482                                              MMsWL
# 61625                                              MMsWL
# 61720  bad language|political|racist humor|sexist jok...
#
# [6940 rows x 4 columns]

# %%
# One-hot encode genres
genres_one_hot = merged['genres'].str.get_dummies()

# One-hot encode tags
tags_one_hot = merged['tag'].str.get_dummies()

# Convert the one-hot encoded dataframes to sparse matrices
genres_sparse = csr_matrix(genres_one_hot.values)
tags_sparse = csr_matrix(tags_one_hot.values)

# Sum one-hot encoded genres and tags
genres_sum = genres_sparse.sum(axis=0)
tags_sum = tags_sparse.sum(axis=0)

print('Genres:')
print(genres_sum)
print('\nTags:')
print(tags_sum)
# Out:
# Genres:
# [[1188  842  430  457 2313  846  263 3364  549   89  750  115  223  463
#   1148  720 1431  272  114]]
#
# Tags:
# [[1 2 1 ... 1 1 1]]

# %%
# sort the samples in alphabetical order
merged = merged.sort_values('movieId')
merged.head(60)
# Out:
#     movieId                                              title  \
# 0         1                                   Toy Story (1995)
# 1         2                                     Jumanji (1995)
# 2         3                            Grumpier Old Men (1995)
# 3         4                           Waiting to Exhale (1995)
# 4         5                 Father of the Bride Part II (1995)
# 5         6                                        Heat (1995)
# 6         7                                     Sabrina (1995)
# 8         9                                Sudden Death (1995)
# 9        10                                   GoldenEye (1995)
# 10       11                     American President, The (1995)
# 11       12                 Dracula: Dead and Loving It (1995)
# 12       13                                       Balto (1995)
# 13       14                                       Nixon (1995)
# 14       15                            Cutthroat Island (1995)
# 15       16                                      Casino (1995)
# 16       17                       Sense and Sensibility (1995)
# 17       18                                  Four Rooms (1995)
# 18       19              Ace Ventura: When Nature Calls (1995)
# 19       20                                 Money Train (1995)
# 20       21                                  Get Shorty (1995)
# 21       22                                     Copycat (1995)
# 22       23                                   Assassins (1995)
# 23       24                                      Powder (1995)
# 24       25                           Leaving Las Vegas (1995)
# 25       26                                     Othello (1995)
# 26       27                                Now and Then (1995)
# 27       28                                  Persuasion (1995)
# 28       29  City of Lost Children, The (Cité des enfants p...
# 29       30  Shanghai Triad (Yao a yao yao dao waipo qiao) ...
# 30       31                             Dangerous Minds (1995)
# 31       32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 33       34                                        Babe (1995)
# 34       35                                  Carrington (1995)
# 35       36                            Dead Man Walking (1995)
# 37       38                                It Takes Two (1995)
# 38       39                                    Clueless (1995)
# 39       40                    Cry, the Beloved Country (1995)
# 40       41                                 Richard III (1995)
# 41       42                             Dead Presidents (1995)
# 42       43                                 Restoration (1995)
# 43       44                               Mortal Kombat (1995)
# 44       45                                  To Die For (1995)
# 45       46               How to Make an American Quilt (1995)
# 46       47                        Seven (a.k.a. Se7en) (1995)
# 47       48                                  Pocahontas (1995)
# 48       49                       When Night Is Falling (1995)
# 49       50                         Usual Suspects, The (1995)
# 51       52                            Mighty Aphrodite (1995)
# 52       53                                    Lamerica (1994)
# 53       54                              Big Green, The (1995)
# 54       55                                     Georgia (1995)
# 56       57                       Home for the Holidays (1995)
# 57       58                  Postman, The (Postino, Il) (1994)
# 59       60                 Indian in the Cupboard, The (1995)
# 60       61                              Eye for an Eye (1996)
# 61       62                          Mr. Holland's Opus (1995)
# 62       63  Don't Be a Menace to South Central While Drink...
# 63       64                               Two if by Sea (1996)
# 64       65                                    Bio-Dome (1996)
# 65       66          Lawnmower Man 2: Beyond Cyberspace (1996)
#
#                                          genres  \
# 0   Adventure|Animation|Children|Comedy|Fantasy
# 1                    Adventure|Children|Fantasy
# 2                                Comedy|Romance
# 3                          Comedy|Drama|Romance
# 4                                        Comedy
# 5                         Action|Crime|Thriller
# 6                                Comedy|Romance
# 8                                        Action
# 9                     Action|Adventure|Thriller
# 10                         Comedy|Drama|Romance
# 11                                Comedy|Horror
# 12                 Adventure|Animation|Children
# 13                                        Drama
# 14                     Action|Adventure|Romance
# 15                                  Crime|Drama
# 16                                Drama|Romance
# 17                                       Comedy
# 18                                       Comedy
# 19           Action|Comedy|Crime|Drama|Thriller
# 20                        Comedy|Crime|Thriller
# 21          Crime|Drama|Horror|Mystery|Thriller
# 22                        Action|Crime|Thriller
# 23                                 Drama|Sci-Fi
# 24                                Drama|Romance
# 25                                        Drama
# 26                               Children|Drama
# 27                                Drama|Romance
# 28       Adventure|Drama|Fantasy|Mystery|Sci-Fi
# 29                                  Crime|Drama
# 30                                        Drama
# 31                      Mystery|Sci-Fi|Thriller
# 33                               Children|Drama
# 34                                Drama|Romance
# 35                                  Crime|Drama
# 37                              Children|Comedy
# 38                               Comedy|Romance
# 39                                        Drama
# 40                                    Drama|War
# 41                           Action|Crime|Drama
# 42                                        Drama
# 43                     Action|Adventure|Fantasy
# 44                        Comedy|Drama|Thriller
# 45                                Drama|Romance
# 46                             Mystery|Thriller
# 47     Animation|Children|Drama|Musical|Romance
# 48                                Drama|Romance
# 49                       Crime|Mystery|Thriller
# 51                         Comedy|Drama|Romance
# 52                              Adventure|Drama
# 53                              Children|Comedy
# 54                                        Drama
# 56                                        Drama
# 57                         Comedy|Drama|Romance
# 59                   Adventure|Children|Fantasy
# 60                               Drama|Thriller
# 61                                        Drama
# 62                                 Comedy|Crime
# 63                               Comedy|Romance
# 64                                       Comedy
# 65                       Action|Sci-Fi|Thriller
#
#                                                   tag
# 0   Owned|imdb top 250|Pixar|Pixar|time travel|chi...
# 1   Robin Williams|time travel|fantasy|based on ch...
# 2   funny|best friend|duringcreditsstinger|fishing...
# 3   based on novel or book|chick flick|divorce|int...
# 4   aging|baby|confidence|contraception|daughter|g...
# 5   imdb top 250|great acting|realistic action|sus...
# 6   remake|chauffeur|fusion|long island|millionair...
# 8          explosive|hostage|terrorist|vice president
# 9   007|Bond|boys with toys|gadgets|secret service...
# 10  Romance|white house|new love|usa president|whi...
# 11                                      dracula|spoof
# 12  Ei muista|alaska|bear attack|dog|dog sled|dog-...
# 13  biography|government|historical figure|preside...
# 14       exotic island|map|pirate|scalp|ship|treasure
# 15  Mafia|Mafia|Martin Scorsese|organized crime|ro...
# 16  chick flick|British|Jane Austen|19th century|a...
# 17  anthology|dark comedy|fast paced|gross|hotel|m...
# 18  detective|childhood classic|Jim Carrey|comedy|...
# 19  new york city|new york subway|sibling relation...
# 20  Crime|Hollywood|movie business|USA|based on no...
# 21  thriller|thriller|thriller|cowardliness|police...
# 22  assassination|bank|caribbean|cat|cia|competiti...
# 23  earnest|elegiac|poignant|reflective|tearjerkin...
# 24  Nicolas Cage|ALCOHOLISM|atmospheric|elegiac|in...
# 25                  friends|jealousy|moor|shakespeare
# 26  1970s|coming of age|female friendship|gynecolo...
# 27  Jane Austen|Ciarán Hinds|Jane Austen|admiral|c...
# 28  dystopia|surreal|bleak|children|kidnapping|ste...
# 29  cabaret|diva|mistress|servant|shanghai|umbrell...
# 30  inspirational|inspirational|inspirational|amus...
# 31  imdb top 250|asylum|biological warfare|dystopi...
# 33                              animals - live action
# 34  conscientious objector|england|independent fil...
# 35  rated-R|Catholicism|religion|charity|court|cou...
# 37  identical twin|matchmaking|orphan|relationship...
# 38         teen movie|teen movie|chick flick|quotable
# 39                                       south africa
# 40         england|kidnapping|king|murder|shakespeare
# 41  1960s|african american|armored truck|bank robb...
# 42  17th century|british monarchy|court|fountain|g...
# 43  based on video game|gore|hand to hand combat|i...
# 44  adultery|gay director|mockumentary|narcissisti...
# 45  advice|extramarital affair|family holiday|gran...
# 46  imdb top 250|detective|neo-noir|twist ending|D...
# 47  Katottava|17th century|animal sidekick|animate...
# 48  lesbian|lesbian director|lgbt|professor|woman ...
# 49  imdb top 250|heist|suspense|thriller|twist end...
# 51  adoption|adoptive father|adoptive mother|child...
# 52                                   independent film
# 53        kids and family|soccer|sport|woman director
# 54                    alcohol|artist|band|drugs|music
# 56  baltimore|family clan|family conflict|generati...
# 57               fisherman|island|letter|poet|postman
# 59  cupboard|games|parallel world|puppet|toy comes...
# 60             grieving parents|gun|rape|self-defense
# 61  apprentice|composer|deaf-mute|disabled|mentor|...
# 62  cousin|date|gang|gangster|hip-hop|hood|parody|...
# 63   Sandra Bullock|island|painting|seasickness|thief
# 64                       biotope|pollution|vegetarian
# 65        computer|hacker|sword fight|virtual reality

# %%
# Combine features (genres and tags) with other movie features
features = pd.concat([merged[['movieId', 'title']], genres_one_hot, tags_one_hot], axis=1)

# Assuming 'features' is a DataFrame containing movie features
features.set_index('movieId', inplace=True)

# Exclude non-numeric columns ('title' in this case) from similarity calculation
numeric_features = features.select_dtypes(include=['number'])
similarities = cosine_similarity(numeric_features)

# Ask the user to input a movie title
user_input = input("Enter a movie title: ")

# Find the index of the movie in the DataFrame that matches the input title
movie_index = features[features['title'].str.lower() == user_input.lower()].index

# Check if the movie exists in the DataFrame
if not movie_index.empty:
    movie_index = movie_index[0]
    if movie_index < len(similarities):
        similar_indices = similarities[movie_index].argsort()[-6:-1][::-1]  # Exclude the movie itself
        similar_movie_ids = numeric_features.iloc[similar_indices].index
        similar_movies = features.loc[similar_movie_ids, 'title']

        # Print recommendations for the input movie title
        print('Recommendations for', user_input)
        print(similar_movies)
    else:
        print("Movie index out of bounds.")
else:
    print("Movie not found.")
# Out:
# Enter a movie title:  Big Green, The (1995)
# Recommendations for Big Green, The (1995)
# movieId
# 5394                      Don't Bother to Knock (1952)
# 32025                             Walk on Water (2004)
# 1165                          Bloody Child, The (1996)
# 2621      Xiu Xiu: The Sent-Down Girl (Tian yu) (1998)
# 102684                        Only God Forgives (2013)
# Name: title, dtype: object

# %%
# Calculate content-based similarity using genres
genres_matrix = merged['genres'].str.get_dummies(sep='|')
genres_similarity = cosine_similarity(genres_matrix)

# Calculate content-based similarity using tags
tags_matrix = merged['tag'].str.get_dummies(sep='|')
tags_similarity = cosine_similarity(tags_matrix)

# Create a mapping between movie titles and indices
title_to_index = {title: idx for idx, title in enumerate(merged['title'])}

# Calculate diversity
pairwise_combinations = list(combinations(merged['title'], 2))
diversity_scores = []
for movie1, movie2 in pairwise_combinations:
    index1 = title_to_index[movie1]
    index2 = title_to_index[movie2]
    diversity_score = 1 - genres_similarity[index1][index2]
    diversity_scores.append(diversity_score)
diversity = sum(diversity_scores) / len(diversity_scores)

# Calculate feature coverage
total_features = set(merged['genres'].str.split('|').sum() + merged['tag'].str.split('|').sum())
recommended_features = set(merged.loc[1:3, 'genres'].str.split('|').sum() + merged.loc[1:3, 'tag'].str.split('|').sum())
feature_coverage = len(recommended_features) / len(total_features)

print(f'Content-Based Similarity (Genres): \n{genres_similarity}\n')
print(f'Content-Based Similarity (Tags): \n{tags_similarity}\n')
print(f'Feature Coverage: {feature_coverage}\n')
print(f'Diversity: {diversity}\n')
